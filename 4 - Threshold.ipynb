# %%
# Import the otsu threshold function
from skimage.filters import threshold_otsu
from skimage import data,color
from common import show_image 

camera_pieces_image =  data.camera()

# Make the image grayscale using rgb2gray
camera_pieces_image_gray = color.rgb2gray(camera_pieces_image)

# Obtain the optimal threshold value with otsu
thresh = threshold_otsu(camera_pieces_image_gray)

# Apply thresholding to the image
binary = camera_pieces_image_gray > thresh

# Show the image
show_image(binary, 'Binary image')

# %%
# Import the try all function
from skimage.filters import try_all_threshold
import matplotlib.pyplot as plt

# Use the try all method on the grayscale image
fig, ax = try_all_threshold(camera_pieces_image_gray, verbose=False)

# Show the resulting plots
plt.show()
